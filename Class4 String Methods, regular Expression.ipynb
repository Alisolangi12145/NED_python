# %%
a = "Pakistan Zindabad"
print(type(a))
print(dir(a))
# Out:
# <class 'str'>
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %% [markdown]
# # All Methods/function , Attributes/property/ fields of string
# * Method_name()
# * Attribute_name
#
# * How can we call method or attribute
#     * Ovject_name.method_name()
#     * object_name.attribute_name

# %%
text ="""pakistan Zindabad!
We love our country.


"""

print(text.capitalize())
# Out:
# Pakistan zindabad!
# we love our country.

# %%
#
text ="""Pakistan ZIndabad!
We love Our Country.


"""

print(text.casefold())
# Out:
# pakistan zindabad!
# we love our country.

# %%
text ="""Pakistan ZIndabad!
We love Our Country.


"""

print(text.lower())
# Out:
# pakistan zindabad!
# we love our country.

# %%
text ="Ali Solangi"

print(len(text))
# Out:
# 11

# %%
text ="Ali Solangi good"

print(text.center(20))
# Out:
#   Ali Solangi good

# %%
text ="Ali Solangi good Morning"

print(text.count("a"))
# Out:
# 1

# %%
text ="Qasim is teachin AI at NED"

print(text.count("Qasim"))
# Out:
# 1

# %%
text ="Muhammad Qasim is teachin AI at NED"

text =text.lower()

print(text.count("qasim"))
# Out:
# 1

# %%
text ="Muhammad Qasim"

text =text.lower()

print(text.count("m")+ text.count("a"))
# Out:
# 7

# %%
text ="Muhammad Qasim"

text =text.lower()

print(text.count("m"),text.count("a"))
# Out:
# 4 3

# %%
text ="Muhammad Qasim"

text =text.lower()

m1=text.count("m")
a1 =text.count("a")

print(type(m1))
print(type(a1))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # Encoding

# %%
txt="My name is stale"
e =txt.encode()
print(e)
# Out:
# b'My name is stale'

# %%
txt = "My name is Ståle"

x = txt.encode()

print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt = "My name is Ståle"

print(txt.encode(encoding="ascii",errors="backslashreplace"))
print(txt.encode(encoding="ascii",errors="ignore"))
print(txt.encode(encoding="ascii",errors="namereplace"))
print(txt.encode(encoding="ascii",errors="replace"))
print(txt.encode(encoding="ascii",errors="xmlcharrefreplace"))
# Out:
# b'My name is St\\xe5le'
# b'My name is Stle'
# b'My name is St\\N{LATIN SMALL LETTER A WITH RING ABOVE}le'
# b'My name is St?le'
# b'My name is St&#229;le'

# %%
text ="Ali Solangi good Morning"

print(text.endswith("g"))
print(text.endswith("Morning"))
# Out:
# True
# True

# %%
text ="Ali Solangi good Morning"

print(text.startswith("A"))
print(text.startswith("Morning"))
# Out:
# True
# False

# %%
text ="Ali Solangi good Morning"

search =input("Start with:")
print(text.startswith(search))
print(text.startswith("Morning"))
# Out:
# Start with:A
# True
# False

# %%
card="""
NED UNIVERSITY
Batch 5
Class:\t Python
Name:\t Ali
Fname: \t Ali Akbar
"""

print(card.expandtabs(20))
# Out:
# NED UNIVERSITY
# Batch 5
# Class:               Python
# Name:                Ali
# Fname:               Ali Akbar

# %%
help(text.startswith)
# Out:
# Help on built-in function startswith:
#
# startswith(...) method of builtins.str instance
#     S.startswith(prefix[, start[, end]]) -> bool
#
#     Return True if S starts with the specified prefix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     prefix can also be a tuple of strings to try.

# %%
name="MuHaMad QaSim"
# ?name.lower

# %%
# Out:
# Help on built-in function startswith:
#
# startswith(...) method of builtins.str instance
#     S.startswith(prefix[, start[, end]]) -> bool
#
#     Return True if S starts with the specified prefix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     prefix can also be a tuple of strings to try.

# %%
name ="    Ali Solangi   "

print(name)

name=name.strip()
print(name)
# Out:
#     Ali Solangi
# Ali Solangi

# %%
name ="    Ali Solangi   "

print(name)

name=name.lstrip()
print(name)
# Out:
#     Ali Solangi
# Ali Solangi

# %%
name ="    Ali Solangi   "

print(name)

name=name.rstrip()
print(name)
# Out:
#     Ali Solangi
#     Ali Solangi

# %%
name ="Ali Solangi"
name=name.lower()
name=name.replace("solangi","Akbar")

print(name)
# Out:
# ali Akbar

# %%
name ="Ali Solangi Solangi Solangi "
name=name.lower()
name=name.replace("solangi","Akbar",-1)

print(name)
# Out:
# ali Akbar Akbar Akbar

# %%
name ="Ali solangi"

name.index("solangi")
# Out:
# 4

# %%
name.find("solangi")
# Out:
# 4

# %% [markdown]
# # Additional Task

# %%
text ="""
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
"""

import re


text =text.replace("-","")

cnic = re.findall('\d{13}',text)
print(len(cnic))
cnic
# Out:
# 22
# ['4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269',
#  '4320554633269']

# %%
text ="""
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
4320554633269
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
43205-5463326-9
"""

import re
import pandas as pd

text =text.replace("-","")
#cnic =list(set(cnic))

cnic = re.findall('\d{13}',text)
print(len(cnic))


df = pd.DataFrame({"Cnice":cnic})

df.to_excel("Class3_attendance.xlsx", index=False)
df
# Out:
# 22
#             Cnice
# 0   4320554633269
# 1   4320554633269
# 2   4320554633269
# 3   4320554633269
# 4   4320554633269
# 5   4320554633269
# 6   4320554633269
# 7   4320554633269
# 8   4320554633269
# 9   4320554633269
# 10  4320554633269
# 11  4320554633269
# 12  4320554633269
# 13  4320554633269
# 14  4320554633269
# 15  4320554633269
# 16  4320554633269
# 17  4320554633269
# 18  4320554633269
# 19  4320554633269
# 20  4320554633269
# 21  4320554633269

# %%
# individual character

text ="""
Veronica Merritt
Colten Richmond
Whitney Walton
Dominick Andrews
Payton Cannon
Archie Love
Avianna Dunn
Dawson Klein
Elianna Boyle
Robin Rivers
Kiana Newton
Santino Doyle
Annalise Wolfe
Donovan Hickman
Scarlette Livingston
Ambrose Coffey
Paola Wagner
Enzo Bowers
Elisa Bullock
Ben Cantu
Galilea Dickson
Maxton Byrd
Giselle Wallace
Chase Li
Paige Branch
Keenan Gomez
Natalie Anderson
Jacob Jacobson
Royal Phan
Maison Farley
Wrenley Wiggins
Azariah Crawford
Aubree Villalobos
Reuben Buckley
Shepherd Ball
Abby Douglas
Derek Gallegos
Ari Cantrell
Harris Bernard
Barbara Jordan
Sawyer Wilkerson
Janiyah Sampson
Cain Cabrera
Daleyza Crane
Fox Figueroa
Lilith Bravo
Genesis Schroeder
Cameron Maddox
Lyric Mathis
Anne Person
Moses Baker
Isla Madden
Everest Shah
Angelica Davis
Amos Rowe
Amos Rowe
Matilda Carey
Watson Adkins
Emelia Horton
Emelia Horton

"""

import re
name = re.findall('.',text)
name
# Out:
# ['V',
#  'e',
#  'r',
#  'o',
#  'n',
#  'i',
#  'c',
#  'a',
#  ' ',
#  'M',
#  'e',
#  'r',
#  'r',
#  'i',
#  't',
#  't',
#  'C',
#  'o',
#  'l',
#  't',
#  'e',
#  'n',
#  ' ',
#  'R',
#  'i',
#  'c',
#  'h',
#  'm',
#  'o',
#  'n',
#  'd',
#  'W',
#  'h',
#  'i',
#  't',
#  'n',
#  'e',
#  'y',
#  ' ',
#  'W',
#  'a',
#  'l',
#  't',
#  'o',
#  'n',
#  'D',
#  'o',
#  'm',
#  'i',
#  'n',
#  'i',
#  'c',
#  'k',
#  ' ',
#  'A',
#  'n',
#  'd',
#  'r',
#  'e',
#  'w',
#  's',
#  'P',
#  'a',
#  'y',
#  't',
#  'o',
#  'n',
#  ' ',
#  'C',
#  'a',
#  'n',
#  'n',
#  'o',
#  'n',
#  'A',
#  'r',
#  'c',
#  'h',
#  'i',
#  'e',
#  ' ',
#  'L',
#  'o',
#  'v',
#  'e',
#  'A',
#  'v',
#  'i',
#  'a',
#  'n',
#  'n',
#  'a',
#  ' ',
#  'D',
#  'u',
#  'n',
#  'n',
#  'D',
#  'a',
#  'w',
#  's',
#  'o',
#  'n',
#  ' ',
#  'K',
#  'l',
#  'e',
#  'i',
#  'n',
#  'E',
#  'l',
#  'i',
#  'a',
#  'n',
#  'n',
#  'a',
#  ' ',
#  'B',
#  'o',
#  'y',
#  'l',
#  'e',
#  'R',
#  'o',
#  'b',
# ...

# %%
# individual character

text ="""
Veronica Merritt
Colten Richmond
Whitney Walton
Dominick Andrews
Payton Cannon
Archie Love
Avianna Dunn
Dawson Klein
Elianna Boyle
Robin Rivers
Kiana Newton
Santino Doyle
Annalise Wolfe
Donovan Hickman
Scarlette Livingston
Ambrose Coffey
Paola Wagner
Enzo Bowers
Elisa Bullock
Ben Cantu
Galilea Dickson
Maxton Byrd
Giselle Wallace
Chase Li
Paige Branch
Keenan Gomez
Natalie Anderson
Jacob Jacobson
Royal Phan
Maison Farley
Wrenley Wiggins
Azariah Crawford
Aubree Villalobos
Reuben Buckley
Shepherd Ball
Abby Douglas
Derek Gallegos
Ari Cantrell
Harris Bernard
Barbara Jordan
Sawyer Wilkerson
Janiyah Sampson
Cain Cabrera
Daleyza Crane
Fox Figueroa
Lilith Bravo
Genesis Schroeder
Cameron Maddox
Lyric Mathis
Anne Person
Moses Baker
Isla Madden
Everest Shah
Angelica Davis
Amos Rowe
Amos Rowe
Matilda Carey
Watson Adkins
Emelia Horton
Emelia Horton

"""

import re
name = re.findall('(.+)',text)
name
# Out:
# ['Veronica Merritt',
#  'Colten Richmond',
#  'Whitney Walton',
#  'Dominick Andrews',
#  'Payton Cannon',
#  'Archie Love',
#  'Avianna Dunn',
#  'Dawson Klein',
#  'Elianna Boyle',
#  'Robin Rivers',
#  'Kiana Newton',
#  'Santino Doyle',
#  'Annalise Wolfe',
#  'Donovan Hickman',
#  'Scarlette Livingston',
#  'Ambrose Coffey',
#  'Paola Wagner',
#  'Enzo Bowers',
#  'Elisa Bullock',
#  'Ben Cantu',
#  'Galilea Dickson',
#  'Maxton Byrd',
#  'Giselle Wallace',
#  'Chase Li',
#  'Paige Branch',
#  'Keenan Gomez',
#  'Natalie Anderson',
#  'Jacob Jacobson',
#  'Royal Phan',
#  'Maison Farley',
#  'Wrenley Wiggins',
#  'Azariah Crawford',
#  'Aubree Villalobos',
#  'Reuben Buckley',
#  'Shepherd Ball',
#  'Abby Douglas',
#  'Derek Gallegos',
#  'Ari Cantrell',
#  'Harris Bernard',
#  'Barbara Jordan',
#  'Sawyer Wilkerson',
#  'Janiyah Sampson',
#  'Cain Cabrera',
#  'Daleyza Crane',
#  'Fox Figueroa',
#  'Lilith Bravo',
#  'Genesis Schroeder',
#  'Cameron Maddox',
#  'Lyric Mathis',
# ...

# %%
# only will be shown those with whome time is mentioned 

text ="""
Veronica Merritt7:23 pm
Colten Richmond8:30 pm
Whitney Walton10:23 pm
Dominick Andrews11:12 pm
Payton Cannon
Archie Love
Avianna Dunn
Dawson Klein
Elianna Boyle
Robin Rivers
Kiana Newton
Santino Doyle
Annalise Wolfe
Donovan Hickman
Scarlette Livingston
Ambrose Coffey
Paola Wagner
Enzo Bowers
Elisa Bullock
Ben Cantu
Galilea Dickson
Maxton Byrd
Giselle Wallace
Chase Li
Paige Branch
Keenan Gomez
Natalie Anderson
Jacob Jacobson
Royal Phan
Maison Farley
Wrenley Wiggins
Azariah Crawford
Aubree Villalobos
Reuben Buckley
Shepherd Ball
Abby Douglas
Derek Gallegos
Ari Cantrell
Harris Bernard
Barbara Jordan
Sawyer Wilkerson
Janiyah Sampson
Cain Cabrera
Daleyza Crane
Fox Figueroa
Lilith Bravo
Genesis Schroeder
Cameron Maddox
Lyric Mathis
Anne Person
Moses Baker
Isla Madden
Everest Shah
Angelica Davis
Amos Rowe
Amos Rowe
Matilda Carey
Watson Adkins01:34 pm
Emelia Horton
Emelia Horton12:23 pm

"""

import re
name = re.findall('(.+)\d+:\d+ pm',text)
name
# Out:
# ['Veronica Merritt',
#  'Colten Richmond',
#  'Whitney Walton1',
#  'Dominick Andrews1',
#  'Watson Adkins0',
#  'Emelia Horton1']

# %%
# only will be shown those with whome time is mentioned 

text ="""
Veronica Merritt7:23 pm
Colten Richmond8:30 pm
Whitney Walton10:23 pm
Dominick Andrews11:12 pm
Payton Cannon
Archie Love
Avianna Dunn
Dawson Klein
Elianna Boyle
Robin Rivers
Kiana Newton
Santino Doyle
Annalise Wolfe
Donovan Hickman
Scarlette Livingston
Ambrose Coffey
Paola Wagner
Enzo Bowers
Elisa Bullock
Ben Cantu
Galilea Dickson
Maxton Byrd
Giselle Wallace
Chase Li
Paige Branch
Keenan Gomez
Natalie Anderson
Jacob Jacobson
Royal Phan
Maison Farley
Wrenley Wiggins
Azariah Crawford
Aubree Villalobos
Reuben Buckley
Shepherd Ball
Abby Douglas
Derek Gallegos
Ari Cantrell
Harris Bernard
Barbara Jordan
Sawyer Wilkerson
Janiyah Sampson
Cain Cabrera
Daleyza Crane
Fox Figueroa
Lilith Bravo
Genesis Schroeder
Cameron Maddox
Lyric Mathis
Anne Person
Moses Baker
Isla Madden
Everest Shah
Angelica Davis
Amos Rowe
Amos Rowe
Matilda Carey
Watson Adkins01:34 pm
Emelia Horton
Emelia Horton12:23 pm

"""

import re
name = re.findall('(.+)',text)
name
# Out:
# ['Veronica Merritt7:23 pm',
#  'Colten Richmond8:30 pm',
#  'Whitney Walton10:23 pm',
#  'Dominick Andrews11:12 pm',
#  'Payton Cannon',
#  'Archie Love',
#  'Avianna Dunn',
#  'Dawson Klein',
#  'Elianna Boyle',
#  'Robin Rivers',
#  'Kiana Newton',
#  'Santino Doyle',
#  'Annalise Wolfe',
#  'Donovan Hickman',
#  'Scarlette Livingston',
#  'Ambrose Coffey',
#  'Paola Wagner',
#  'Enzo Bowers',
#  'Elisa Bullock',
#  'Ben Cantu',
#  'Galilea Dickson',
#  'Maxton Byrd',
#  'Giselle Wallace',
#  'Chase Li',
#  'Paige Branch',
#  'Keenan Gomez',
#  'Natalie Anderson',
#  'Jacob Jacobson',
#  'Royal Phan',
#  'Maison Farley',
#  'Wrenley Wiggins',
#  'Azariah Crawford',
#  'Aubree Villalobos',
#  'Reuben Buckley',
#  'Shepherd Ball',
#  'Abby Douglas',
#  'Derek Gallegos',
#  'Ari Cantrell',
#  'Harris Bernard',
#  'Barbara Jordan',
#  'Sawyer Wilkerson',
#  'Janiyah Sampson',
#  'Cain Cabrera',
#  'Daleyza Crane',
#  'Fox Figueroa',
#  'Lilith Bravo',
#  'Genesis Schroeder',
# ...

# %%
text ="""
Veronica Merritt7:23 PM
Colten Richmond8:30 AM
Whitney Walton
Dominick Andrews
Payton Cannon
Archie Love
Avianna Dunn
Dawson Klein
Elianna Boyle
Robin Rivers
Kiana Newton
Santino Doyle
Annalise Wolfe
Donovan Hickman
Scarlette Livingston
Ambrose Coffey
Paola Wagner
Enzo Bowers
Elisa Bullock
Ben Cantu
Galilea Dickson
Maxton Byrd
Giselle Wallace
Chase Li
Paige Branch
Keenan Gomez
Natalie Anderson
Jacob Jacobson
Royal Phan
Maison Farley
Wrenley Wiggins
Azariah Crawford
Aubree Villalobos
Reuben Buckley
Shepherd Ball
Abby Douglas
Derek Gallegos
Ari Cantrell
Harris Bernard
Barbara Jordan
Sawyer Wilkerson
Janiyah Sampson
Cain Cabrera
Daleyza Crane
Fox Figueroa
Lilith Bravo
Genesis Schroeder
Cameron Maddox
Lyric Mathis
Anne Person
Moses Baker
Isla Madden
Everest Shah
Angelica Davis
Amos Rowe
Amos Rowe
Matilda Carey
Watson Adkins01:34 PM
Emelia Horton
Emelia Horton12:23 AM

"""

import re
name = re.findall('\w+',text)
name
# Out:
# ['Veronica',
#  'Merritt7',
#  '23',
#  'PM',
#  'Colten',
#  'Richmond8',
#  '30',
#  'AM',
#  'Whitney',
#  'Walton',
#  'Dominick',
#  'Andrews',
#  'Payton',
#  'Cannon',
#  'Archie',
#  'Love',
#  'Avianna',
#  'Dunn',
#  'Dawson',
#  'Klein',
#  'Elianna',
#  'Boyle',
#  'Robin',
#  'Rivers',
#  'Kiana',
#  'Newton',
#  'Santino',
#  'Doyle',
#  'Annalise',
#  'Wolfe',
#  'Donovan',
#  'Hickman',
#  'Scarlette',
#  'Livingston',
#  'Ambrose',
#  'Coffey',
#  'Paola',
#  'Wagner',
#  'Enzo',
#  'Bowers',
#  'Elisa',
#  'Bullock',
#  'Ben',
#  'Cantu',
#  'Galilea',
#  'Dickson',
#  'Maxton',
#  'Byrd',
#  'Giselle',
#  'Wallace',
#  'Chase',
#  'Li',
#  'Paige',
#  'Branch',
#  'Keenan',
#  'Gomez',
#  'Natalie',
#  'Anderson',
#  'Jacob',
#  'Jacobson',
#  'Royal',
#  'Phan',
#  'Maison',
#  'Farley',
#  'Wrenley',
#  'Wiggins',
#  'Azariah',
#  'Crawford',
#  'Aubree',
#  'Villalobos',
#  'Reuben',
#  'Buckley',
#  'Shepherd',
#  'Ball',
#  'Abby',
#  'Douglas',
#  'Derek',
# ...
